# %% [markdown]
# <a href="https://colab.research.google.com/github/CHOISEONGGU/MachineLearning_ChoiSG/blob/main/CHOISEONGGU/%EA%B3%B5%EB%B6%80%EC%9E%90%EB%A3%8C/ch08_ML_09_KMeansClustering_ChoiSG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 주요 라이브러리 import
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# https://github.com/BigData23th/Data/raw/main/example_cluster.csv
df = pd.read_csv('https://github.com/BigData23th/Data/raw/main/example_cluster.csv')
df
# Out:
#          var_1     var_2
# 0     3.264413  6.929164
# 1     0.220814  2.251631
# 2    -8.786197 -8.333582
# 3    -0.008547  2.630791
# 4     4.912903  6.888520
# ..         ...       ...
# 995   4.678232  7.704404
# 996   5.250715  6.930948
# 997 -11.818752 -5.609853
# 998   0.613725  3.809334
# 999   3.516961  8.486305
#
# [1000 rows x 2 columns]

# %%
# 산점도
sns.scatterplot(x='var_1', y='var_2', data=df)
plt.show()

# %%
# K 평균 군집화 (K Means Clustering)
from sklearn.cluster import KMeans

# %%
# n_clusters : 나눠줄 클러스터(묶음)의 수
kmeans_model = KMeans(n_clusters=3, random_state=2023)

# %%
# 지도 -> X, y
# 비지도 -> X
kmeans_model.fit(df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3, random_state=2023)

# %%
# 예측
# 군집화 분석을 통해 분석된 K개의 그룹과 각 데이터가 어느 그룹에 속했는지
# fit_predict (fit하고 바로 예측)
kmeans_model.predict(df)
pred = kmeans_model.fit_predict(df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# label
# KMeans 산출한 그룹들을 label로 주입
df['label'] = pred

# %%
# 산점도2 - label을 적용한
# sns.scatterplot(
#     x='var_1', y='var_2', data=df,
#     hue='label'
# )
sns.scatterplot(
    x='var_1', y='var_2', data=df,
    hue='label', palette='rainbow'
)
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %%
# 이너셔 (inertia)
# - 각 그룹에서의 중심과 각 그룹에 해당하는 데이터 간의 거리에 대한 합
kmeans_model.inertia_
# Out:
# 3090.03323707666

# %%
# k가 엄청 많을 경우
kmeans_model2 = KMeans(n_clusters=500, random_state=2023)
kmeans_model2.fit(df)
kmeans_model2.inertia_
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# 6.268280634496824

# %%
df['label2'] = kmeans_model2.predict(df)

# %%
df.label2
# Out:
# 0      391
# 1      338
# 2      479
# 3      178
# 4       53
#       ...
# 995      5
# 996    389
# 997    160
# 998     34
# 999    186
# Name: label2, Length: 1000, dtype: int32

# %%
sns.scatterplot(
    x='var_1', y='var_2', data=df,
    hue='label2', palette='rainbow'
)
# Out:
# <Axes: xlabel='var_1', ylabel='var_2'>

# %%
# 적절한 k값 설정 -> 엘보우 기법
df = df.drop(['label', 'label2'], axis=1)
df.columns
# Out:
# Index(['var_1', 'var_2'], dtype='object')

# %%
# inertia 거리의 변화폭이 둔화되는 지점 -> 꺾이는 지점
distance = []
for k in range(2, 10): # k : 2-9
    k_model = KMeans(n_clusters=k, random_state=2023)
    k_model.fit(df) # fit만 시켜도 inertia_ 생성
    distance.append(k_model.inertia_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
distance
# Out:
# [9741.810795093243,
#  3090.03323707666,
#  2716.500656944687,
#  2381.6942027423693,
#  2053.3584110460656,
#  1826.5689225650444,
#  1582.2835873213185,
#  1366.9652841499978]

# %%
# 선 차트
sns.lineplot(x=range(2, 10), y=distance)
# 엘보우 : 직관적이고 편리하긴 하나, 객관적 건 아님 -> 사람이 판단
# Out:
# <Axes: >

# %%
for i in range(1, len(distance)):
    # 기울기 -> x 증가 -> y가 증가
    difference = abs(distance[i] - distance[i-1])
    print(f"{i+1}->{i+2}", difference)
# Out:
# 2->3 6651.777558016583
# 3->4 373.5325801319732
# 4->5 334.8064542023176
# 5->6 328.33579169630366
# 6->7 226.78948848102118
# 7->8 244.28533524372597
# 8->9 215.31830317132062

# %%
# 이상거래 데이터 -> 단순화
# https://github.com/BigData23th/Data/raw/main/customer.csv
df = pd.read_csv('https://github.com/BigData23th/Data/raw/main/customer.csv')

# %%
df
# Out:
#                   cc_num        category     amt
# 0       2703186189652095            misc    4.97
# 1           630423337322         grocery  107.23
# 2         38859492057661   entertainment  220.11
# 3       3534093764340240   gas_transport   45.00
# 4        375534208663984            misc   41.96
# ...                  ...             ...     ...
# 240449  4716561796955522        shopping    4.93
# 240450    30074693890476        shopping  140.12
# 240451    30404291151692  health_fitness   37.79
# 240452  4922710831011201   entertainment   17.50
# 240453   213112402583773        shopping   25.49
#
# [240454 rows x 3 columns]

# %%
df.head()
# Out:
#              cc_num       category     amt
# 0  2703186189652095           misc    4.97
# 1      630423337322        grocery  107.23
# 2    38859492057661  entertainment  220.11
# 3  3534093764340240  gas_transport   45.00
# 4   375534208663984           misc   41.96

# %%
df.tail()
# Out:
#                   cc_num        category     amt
# 240449  4716561796955522        shopping    4.93
# 240450    30074693890476        shopping  140.12
# 240451    30404291151692  health_fitness   37.79
# 240452  4922710831011201   entertainment   17.50
# 240453   213112402583773        shopping   25.49

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240454 entries, 0 to 240453
# Data columns (total 3 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   cc_num    240454 non-null  int64
#  1   category  240454 non-null  object
#  2   amt       240454 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 5.5+ MB

# %%
df.describe(include='all')
# Out:
#               cc_num  category            amt
# count   2.404540e+05    240454  240454.000000
# unique           NaN        11            NaN
# top              NaN  shopping            NaN
# freq             NaN     40200            NaN
# mean    3.365543e+17       NaN      69.758079
# std     1.191447e+18       NaN     150.060270
# min     6.049559e+10       NaN       1.000000
# 25%     2.131124e+14       NaN       9.740000
# 50%     2.720433e+15       NaN      47.530000
# 75%     4.642255e+15       NaN      82.950000
# max     4.956829e+18       NaN   21437.710000

# %%
# cc_num : credit card -> 카드번호 -> 특정 고객
df.cc_num.nunique()
# Out:
# 100

# %%
# category별로 고객들이 얼마나 소비를 하냐
customer = pd.get_dummies(df, columns=['category'])
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240454 entries, 0 to 240453
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   cc_num                   240454 non-null  int64
#  1   amt                      240454 non-null  float64
#  2   category_entertainment   240454 non-null  uint8
#  3   category_food_dining     240454 non-null  uint8
#  4   category_gas_transport   240454 non-null  uint8
#  5   category_grocery         240454 non-null  uint8
#  6   category_health_fitness  240454 non-null  uint8
#  7   category_home            240454 non-null  uint8
#  8   category_kids_pets       240454 non-null  uint8
#  9   category_misc            240454 non-null  uint8
#  10  category_personal_care   240454 non-null  uint8
#  11  category_shopping        240454 non-null  uint8
#  12  category_travel          240454 non-null  uint8
# dtypes: float64(1), int64(1), uint8(11)
# ...

# %%
# iloc -> 정수 인덱스로 행, 열을 가져오겠다 (인덱서)
# : -> 전체, [행, 열] => 전체 행 중에 2번째 이후 (경계 포함) 열들만 표시하겠다
customer.iloc[:, 2:]
# Out:
#         category_entertainment  category_food_dining  category_gas_transport  \
# 0                            0                     0                       0
# 1                            0                     0                       0
# 2                            1                     0                       0
# 3                            0                     0                       1
# 4                            0                     0                       0
# ...                        ...                   ...                     ...
# 240449                       0                     0                       0
# 240450                       0                     0                       0
# 240451                       0                     0                       0
# 240452                       1                     0                       0
# 240453                       0                     0                       0
#
# ...

# %%
# 특정 카테고리 포함 여부 (1, 0)
for col_name in customer.iloc[:,2:].columns: # 범주들 이름으로 for문 (반복)
    # 트랜잭션, 거래, 행 (데이터에서의 행)
    # print(col_name)
    # 기존에 있는 컬럼(열)에 새로운 값을 연산
    customer[col_name] = customer[col_name] * customer['amt']   # 특정한 카테고리에 남은 애들만 남겠지
    # 특정 범주(카테고리 포함 여부) : customer[col_name] (1, 0)
    # 소비액 : customer['amt']
    # -> 특정 카테고리에 대한 소비액
    # 한 행 -> 거래 => 열 -> 거래가 속한 범주의 열이라면 amt랑 곱해진 소비액 나올 거고,
    # 나머지 소속되지 않은 경우에 -> 0만 있을 것

# %%
customer
# Out:
#                   cc_num     amt  category_entertainment  \
# 0       2703186189652095    4.97                    0.00
# 1           630423337322  107.23                    0.00
# 2         38859492057661  220.11                  220.11
# 3       3534093764340240   45.00                    0.00
# 4        375534208663984   41.96                    0.00
# ...                  ...     ...                     ...
# 240449  4716561796955522    4.93                    0.00
# 240450    30074693890476  140.12                    0.00
# 240451    30404291151692   37.79                    0.00
# 240452  4922710831011201   17.50                   17.50
# 240453   213112402583773   25.49                    0.00
#
#         category_food_dining  category_gas_transport  category_grocery  \
# 0                        0.0                     0.0              0.00
# 1                        0.0                     0.0            107.23
# ...

# %%
# cc_num 별로 합계를 해주겠다
# 카드번호별로 groupby -> sum()
customer_agg = customer.groupby('cc_num').sum()
customer_agg
# cc_num별 총 소비액인 amt
# 각기 category별 cc_num의 소비액인 각자 열
# -> 총 소비 또는 각 범주별 소비를 통해서 '분류', '군집화'가 가능
# Out:
#                            amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109           48149.62                 3169.74               4043.46
# 571365235126         259784.87                13864.51               9055.51
# 571465035400         270081.63                16162.98              15448.75
# 630412733309          41959.52                 3212.46               1543.16
# 630423337322         244612.73                12786.75               6905.07
# ...                        ...                     ...                   ...
# 4512828414983801773  250072.42                13951.22               9175.56
# 4599735407877245080   96104.05                 6065.69              10049.34
# 4666314527820883145   73275.54                 4612.23               3079.99
# 4725837176265195730   87506.06                 5431.42               3506.19
# 4956828990005111019  218900.92                17747.25              11000.09
#
# ...

# %%
customer_agg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 60495593109 to 4956828990005111019
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   amt                      100 non-null    float64
#  1   category_entertainment   100 non-null    float64
#  2   category_food_dining     100 non-null    float64
#  3   category_gas_transport   100 non-null    float64
#  4   category_grocery         100 non-null    float64
#  5   category_health_fitness  100 non-null    float64
#  6   category_home            100 non-null    float64
#  7   category_kids_pets       100 non-null    float64
#  8   category_misc            100 non-null    float64
#  9   category_personal_care   100 non-null    float64
#  10  category_shopping        100 non-null    float64
#  11  category_travel          100 non-null    float64
# dtypes: float64(12)
# memory usage: 10.2 KB

# %%
# 스케일러 -> 표준화 스케일러 (Standard Scaler)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
# 스케일링을 하고 나서 데이터
scaled = scaler.fit_transform(customer_agg)
scaled # numpy array
# Out:
# array([[-1.40232671, -1.13561684, -0.97106905, ..., -1.07025953,
#         -1.14142374, -0.61993021],
#        [ 1.07940687,  0.41407488,  0.16887956, ...,  1.80734981,
#          0.65996745, -0.22258695],
#        [ 1.20015148,  0.74712739,  1.62296823, ...,  0.12782479,
#          1.29993842,  2.7668909 ],
#        ...,
#        [-1.10768846, -0.9265974 , -1.1902022 , ..., -0.97473624,
#         -0.66458252,  0.19333459],
#        [-0.94081475, -0.80789527, -1.09326659, ..., -0.89572163,
#         -0.70809415,  0.95453742],
#        [ 0.59998262,  0.97669101,  0.61115793, ..., -0.39803373,
#         -0.02063061, -0.08679376]])

# %%
scaled_df = pd.DataFrame(scaled, columns = customer_agg.columns, index=customer_agg.index)

# %%
scaled_df
# Out:
#                           amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109         -1.402327               -1.135617             -0.971069
# 571365235126         1.079407                0.414075              0.168880
# 571465035400         1.200151                0.747127              1.622968
# 630412733309        -1.474915               -1.129427             -1.539741
# 630423337322         0.901491                0.257905             -0.320220
# ...                       ...                     ...                   ...
# 4512828414983801773  0.965514                0.426639              0.196184
# 4599735407877245080 -0.839991               -0.715988              0.394918
# 4666314527820883145 -1.107688               -0.926597             -1.190202
# 4725837176265195730 -0.940815               -0.807895             -1.093267
# 4956828990005111019  0.599983                0.976691              0.611158
#
# ...

# %%
# 엘보우 기법
distance = []
for k in range(2, 10): # 끝경계 포함 X
    k_model = KMeans(n_clusters=k, random_state=2023)
    k_model.fit(scaled_df)
    distance.append(k_model.inertia_)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
for i in range(1, len(distance)):
    # 기울기 -> x 증가 -> y가 증가
    difference = abs(distance[i] - distance[i-1])
    print(f"{i+1}->{i+2}", difference)
# Out:
# 2->3 201.40427805646084
# 3->4 129.79866232476707
# 4->5 71.88588190549638
# 5->6 39.26218952141784
# 6->7 29.991125227819936
# 7->8 32.21738388141594
# 8->9 26.85439507521454

# %%
sns.lineplot(x=range(2, 10), y=distance)
# Out:
# <Axes: >

# %%
# 실루엣 계수
# - 이너셔(inertia) : 그룹(클러스터)의 중심으로부터 다른 요소들간의 거리
# - 실루엣 계수 : 클러스터 내부의 평균 거리 + 최근접한 다른 클러스터와의 평균 거리
from sklearn.metrics import silhouette_score

# %%
silhouette = []
for k in range(2, 10):
    k_model = KMeans(n_clusters=k, random_state=2023)
    # 실제의 데이터 값과, 분류된 라벨을 통해서 클러스터 내부 및 클러스터 간 거리를 계산
    labels = k_model.fit_predict(scaled_df)
    silhouette.append(silhouette_score(scaled_df, labels))
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
silhouette
# Out:
# [0.3717625086081594,
#  0.37507693866618963,
#  0.4345029210702488,
#  0.3930850775191427,
#  0.4011399672224946,
#  0.3633645461295395,
#  0.37593056059521024,
#  0.3929606215601082]

# %%
# 실루엣 계수는 더 클 수록 좋은 분류를 하고 있는 것
sns.lineplot(x=range(2 ,10), y=silhouette)
# Out:
# <Axes: >

# %%
k_model = KMeans(n_clusters=4, random_state=2023)
labels = k_model.fit_predict(scaled_df)
# Out:
# /usr/local/lib/python3.9/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
scaled_df['label'] = labels

# %%
scaled_df
# Out:
#                           amt  category_entertainment  category_food_dining  \
# cc_num
# 60495593109         -1.402327               -1.135617             -0.971069
# 571365235126         1.079407                0.414075              0.168880
# 571465035400         1.200151                0.747127              1.622968
# 630412733309        -1.474915               -1.129427             -1.539741
# 630423337322         0.901491                0.257905             -0.320220
# ...                       ...                     ...                   ...
# 4512828414983801773  0.965514                0.426639              0.196184
# 4599735407877245080 -0.839991               -0.715988              0.394918
# 4666314527820883145 -1.107688               -0.926597             -1.190202
# 4725837176265195730 -0.940815               -0.807895             -1.093267
# 4956828990005111019  0.599983                0.976691              0.611158
#
# ...

# %%
scaled_df_mean = scaled_df.groupby('label').mean()
scaled_df_mean
# Out:
#             amt  category_entertainment  category_food_dining  \
# label
# 0      0.311574                0.149105              0.212407
# 1     -0.858082               -0.739555             -0.758078
# 2      1.908120                2.155375              1.796299
# 3      1.000533                0.776166              1.036432
#
#        category_gas_transport  category_grocery  category_health_fitness  \
# label
# 0                    1.025558          0.109070                 0.452339
# 1                   -0.601061         -0.653905                -0.837854
# 2                   -0.490418          2.290553                 1.155923
# 3                   -0.749213          0.310577                 1.175961
#
#        category_home  category_kids_pets  category_misc  \
# label
# 0           0.369237            0.716395       0.378376
# 1          -0.832432           -0.866100      -0.701383
# 2           0.943950            1.255997       2.005393
# ...

# %%
scaled_df_count = scaled_df.groupby('label').count().amt
scaled_df_count
# Out:
# label
# 0    37
# 1    45
# 2    10
# 3     8
# Name: amt, dtype: int64

# %%
scaled_df_count = scaled_df_count.rename('count')
scaled_df_all = scaled_df_mean.join(scaled_df_count)

# %%
scaled_df_all
# Out:
#             amt  category_entertainment  category_food_dining  \
# label
# 0      0.311574                0.149105              0.212407
# 1     -0.858082               -0.739555             -0.758078
# 2      1.908120                2.155375              1.796299
# 3      1.000533                0.776166              1.036432
#
#        category_gas_transport  category_grocery  category_health_fitness  \
# label
# 0                    1.025558          0.109070                 0.452339
# 1                   -0.601061         -0.653905                -0.837854
# 2                   -0.490418          2.290553                 1.155923
# 3                   -0.749213          0.310577                 1.175961
#
#        category_home  category_kids_pets  category_misc  \
# label
# 0           0.369237            0.716395       0.378376
# 1          -0.832432           -0.866100      -0.701383
# 2           0.943950            1.255997       2.005393
# ...
